# %% [markdown]
# <b><h1>World Population Dataset Analysis (2001–2022)

# %% [markdown]
# <b><h3>📌 Objective </h3></b>
# > Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of total, male, and female populations across countries over the years.

# %% [markdown]
# <b><h3>🔍 About the Dataset </h3></b>
# > We have used a World Population Dataset containing population data of different countries from the year 2001 to 2022.
# | Series Code           | Meaning                                      |
# |-----------------------|----------------------------------------------|
# | SP.POP.TOTL           | Population, total                            |
# | SP.POP.TOTL.FE.IN     | Population, female                           |
# | SP.POP.TOTL.MA.IN     | Population, male                             |
# | SP.POP.TOTL.FE.ZS     | Population, female (% of total population)   |
# | SP.POP.TOTL.MA.ZS     | Population, male (% of total population)    |

# %% [markdown]
# <b><h3>1. Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')

# %% [markdown]
# <b><h3>2. Load the Dataset

# %%
df = pd.read_csv('worldpopulationdata.csv')

# %% [markdown]
# <b><h3>3. Initial Exploration

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %%
df.tail()
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %%
df.shape
# Out:
# (1085, 26)

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# <b><h3>4. Data Cleaning

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# #### Unique values in categorical columns

# %%
print(df['Country Name'].unique())
print('\nTotal no of unique countries:', df['Country Name'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print('\nTotal no of unique country code:', df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %%
print(df['Series Name'].unique())
print(df['Series Code'].unique())
# Out:
# ['Population, total' 'Population, female' 'Population, male'
#  'Population, female (% of total population)'
#  'Population, male (% of total population)']
# ['SP.POP.TOTL' 'SP.POP.TOTL.FE.IN' 'SP.POP.TOTL.MA.IN' 'SP.POP.TOTL.FE.ZS'
#  'SP.POP.TOTL.MA.ZS']

# %% [markdown]
# #### Dropping Unnecessary Columns

# %%
df.drop(['Series Name', 'Country Code'], axis=1, inplace=True)
df.columns
# Out:
# Index(['Series Code', 'Country Name', '2022', '2021', '2020', '2019', '2018',
#        '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# <b><h3>5. Visualizing Total Population

# %% [markdown]
# <b><h4>A. Top 10 Countries by Total Population (2022, 2016, 2010, 2001)

# %%
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']
total_population_sorted = total_population_data.sort_values(by='2022', ascending=False)
total_top_ten_countries = total_population_sorted.head(10)

# %% [markdown]
# #### Bar Plot - Top 10 (2022)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=total_top_ten_countries, palette='coolwarm')
plt.title('Top 10 Countries by Total Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### Bar Plot – Historical Population Trends (2016, 2010, 2001) of the Top 10 Most Populous Countries in 2022

# %%
for year in ['2006', '2010', '2001']:
    plt.figure(figsize=(10,6))
    sns.barplot(x=year, y='Country Name', hue=year, legend=False, data=total_top_ten_countries, palette='coolwarm')
    plt.title(f'Historical Population Trends ({year}) of the Top 10 Most Populous Countries in 2022')
    plt.xlabel('Total Population')
    plt.ylabel('Country')
    plt.show()

# %% [markdown]
# <b><h4>B. Bottom 10 Countries by Total Population (2022, 2016, 2010, 2001)

# %%
total_botton_ten_countries = total_population_data.sort_values(by='2022', ascending=True).head(10)

# %% [markdown]
# #### Bar Plot - Bottom 10 (2022)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=total_botton_ten_countries, palette='viridis')
plt.title('Bottom 10 Countries by Total Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### Bar Plot – Historical Population Trends (2016, 2010, 2001) of the Bottom 10 Most Populous Countries in 2022

# %%
for year in ['2006', '2010', '2001']:
    plt.figure(figsize=(10,6))
    sns.barplot(x=year, y='Country Name', hue=year, legend=False, data=total_botton_ten_countries, palette='viridis')
    plt.title(f'Historical Population Trends ({year}) of the Bottom 10 Most Populous Countries in 2022')
    plt.xlabel('Total Population')
    plt.ylabel('Country')
    plt.show()

# %% [markdown]
# <b><h3>6. Male and Female Population Visualization

# %% [markdown]
# <b><h4>A. Top & Bottom 10 Male Population Countries (2022)

# %%
male_population_data = df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']
male_population_sorted = total_population_data.sort_values(by='2022', ascending=False)
male_top_ten_countries = total_population_sorted.head(10)
male_bottom_ten_countries = total_population_sorted.tail(10)

# %% [markdown]
# #### Top 10 Male Population Countries

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=male_top_ten_countries, palette='crest')
plt.title('Bottom 10 Countries by Male Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### Bottom 10 Male Population Countries

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=male_bottom_ten_countries, palette='crest')
plt.title('Bottom 10 Countries by Male Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# <b><h4>B. Top & Bottom 10 Female Population Countries (2022)

# %%
female_population_data = df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']
female_population_sorted = total_population_data.sort_values(by='2022', ascending=False)
female_top_ten_countries = total_population_sorted.head(10)
female_bottom_ten_countries = total_population_sorted.tail(10)

# %% [markdown]
# #### Top 10 Female Population Countries

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=female_top_ten_countries, palette='magma')
plt.title('Bottom 10 Countries by Female Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### Bottom 10 Female Population Countries

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='2022', y='Country Name', hue='2022', legend=False, data=female_bottom_ten_countries, palette='magma')
plt.title('Bottom 10 Countries by Female Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# <b><h3>7. Stacked Bar Plot for Male and Female Population

# %%
merged_data = pd.merge(male_population_data, female_population_data, on='Country Name', suffixes=('_male', '_female'))
merged_data['Total Population'] = merged_data['2022_male'] + merged_data['2022_female']

# %% [markdown]
# <b><h4>A. Top 10 Countries - Stacked Bar (2022)

# %%
top_10_countries = merged_data.sort_values(by='Total Population', ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Country Name', y='2022_female', data=top_10_countries, color='pink', label='Female')
sns.barplot(x='Country Name', y='2022_male', data=top_10_countries, bottom=top_10_countries['2022_female'], color='blue', label='Male')
plt.title('Bottom 10 Countries by Female Population (2022)')
plt.xlabel('Total Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# <b><h4>B. Bottom 10 Countries - Stacked Bar (2022)

# %%
bottom_10_countries = merged_data.sort_values(by='Total Population', ascending=True).head(10)

# %%
plt.figure(figsize=(12, 6))

# Bar positions
countries = bottom_10_countries['Country Name']
x = range(len(countries))

# Female bars
female = bottom_10_countries['2022_female']
male = bottom_10_countries['2022_male']

# Plot female bars
plt.bar(x, female, color='pink', label='Female')

# Plot male bars stacked on top of female
plt.bar(x, male, bottom=female, color='blue', label='Male')

# Labels and titles
plt.xticks(ticks=x, labels=countries, rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Bottom 10 Countries by Female and Male Population (2022)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <b><h2> 📌 Conclusion </h2></b>
# <ul>
# <li> The population trends highlight the dominance of countries like <b>India</b> and <b>China</b>, which consistently maintain top positions across the years.</li>
# <li> Gender-based visualizations generally show a <b>balanced distribution</b> between males and females across countries.</li>
# <li> The <b>stacked bar plots</b> effectively showcase gender distribution patterns, especially when comparing the top and bottom countries by total population.</li>
# <li> Visualizing earlier years for the <b>2022 top 10 countries</b> reveals steady population growth trends in most of these nations, indicating long-term demographic patterns.</li>
# </ul>
